# %%
import psycopg2
import json
 
try:
    conn = psycopg2.connect(
        host="bankstatementanalysis.cb8amg0w4f2p.ap-south-1.rds.amazonaws.com",
        database="bankStatementAnalysis",
        user="postgres",
        password="Password#1234",
        connect_timeout=3 # Fails quickly if network is blocked
    )
    result =  {"statusCode": 200, "body": "Connection Successful!"}
except Exception as e:
    result =  {"statusCode": 500, "body": f"Network/Auth Error: {str(e)}"}

print(result)
# Out:
# {'statusCode': 200, 'body': 'Connection Successful!'}
